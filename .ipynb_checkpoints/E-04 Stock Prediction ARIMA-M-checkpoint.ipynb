# %% [markdown]
# # E-04 Stock Prediction ARIMA : 017670.KS.csv
#
# ### 2022-11-11 (금)
#
# ### 곽상혁
# https://github.com/docosa2/

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화

# %%
def plot_rolling_statistics(timeseries:pd.Series, window: int=12):    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %% [markdown]
# ## statsmodels 패키지에서 제공하는 adfuller 메서드를 호출

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %% [markdown]
# ## Time Series 생성

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/017670.KS.csv' # SK텔레콤
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.tail()
# Out:
# Date
# 2022-11-15    50100.0
# 2022-11-16    49550.0
# 2022-11-17    49850.0
# 2022-11-18    49550.0
# 2022-11-21    49750.0
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# %%
#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.974060e+00
# p-value                        1.905960e-07
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.440000e+02
# Critical Value (1%)           -3.457438e+00
# Critical Value (5%)           -2.873459e+00
# Critical Value (10%)          -2.573122e+00
# dtype: float64

# %%
#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
# 시계열 분해 결과 그래프
plt.subplot(411)
plt.plot(ts_log, label='Log Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='residual')
plt.legend(loc='best')

plt.tight_layout()

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.621239e+00
# p-value                        6.029633e-09
# #Lags Used                     7.000000e+00
# Number of Observations Used    2.070000e+02
# Critical Value (1%)           -3.462342e+00
# Critical Value (5%)           -2.875606e+00
# Critical Value (10%)          -2.574267e+00
# dtype: float64

# %%
# 학습 및 테스트 데이타 분리
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
import pmdarima as pm
from pmdarima.arima import ndiffs

kpss_diffs = ndiffs(train_data, alpha=0.05, test='kpss', max_d=6)
adf_diffs = ndiffs(train_data, alpha=0.05, test='adf', max_d=6)
n_diffs = max(adf_diffs, kpss_diffs)

print(f"추정된 차수 d = {n_diffs}")
# Out:
# 추정된 차수 d = 1

# %%
### 적정 ARIMA 모수 찾기

# ACF, PACF 그려보기 -> p,q 구하기
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# -------------------------------------------
# 2차 차분 구하기
# diff_2 = diff_1.diff(periods=1).iloc[1:]
# diff_2.plot(title='Difference 2nd')
# augmented_dickey_fuller_test(diff_2)
# -------------------------------------------
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.180396e+00
# p-value                        2.659188e-10
# #Lags Used                     1.300000e+01
# Number of Observations Used    2.300000e+02
# Critical Value (1%)           -3.459106e+00
# Critical Value (5%)           -2.874190e+00
# Critical Value (10%)          -2.573512e+00
# dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA

# ARIMA 모델 훈련과 테스트
# Build and Train  Model
model = ARIMA(train_data, order=(3, 1, 9))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  220
# Model:                 ARIMA(3, 1, 9)   Log Likelihood                 393.033
# Date:                Mon, 21 Nov 2022   AIC                           -760.065
# Time:                        21:34:45   BIC                           -716.007
# Sample:                             0   HQIC                          -742.272
#                                 - 220
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6271      0.305      2.055      0.040       0.029       1.225
# ar.L2         -0.7753      0.125     -6.219      0.000      -1.020      -0.531
# ar.L3          0.7540      0.322      2.341      0.019       0.123       1.385
# ma.L1         -0.5228      0.284     -1.841      0.066      -1.080       0.034
# ma.L2          0.7454      0.224      3.320      0.001       0.305       1.185
# ma.L3         -0.7349      0.357     -2.056      0.040      -1.435      -0.034
# ma.L4         -0.1226      0.301     -0.407      0.684      -0.712       0.467
# ma.L5          0.1715      0.259      0.661      0.508      -0.337       0.680
# ma.L6         -0.0669      0.295     -0.227      0.820      -0.644       0.510
# ma.L7          0.1276      0.198      0.644      0.520      -0.261       0.516
# ma.L8         -0.1234      0.163     -0.759      0.448      -0.442       0.195
# ma.L9         -0.2242      0.157     -1.432      0.152      -0.531       0.083
# sigma2         0.0016      0.000     15.090      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):            162664.91
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.04   Skew:                           -10.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                       134.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# 예측 및 그래프
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# 그래프 그리기 :Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %% [markdown]
# # E-04 Stock Prediction ARIMA : 005490.KS.csv
#
# ### 2022-11-11 (금)
#
# ### 곽상혁
# https://github.com/docosa2/

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화

# %%
def plot_rolling_statistics(timeseries:pd.Series, window: int=12):    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %% [markdown]
# ## statsmodels 패키지에서 제공하는 adfuller 메서드를 호출

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %% [markdown]
# ## Time Series 생성

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/005490.KS.csv' # 포스코 홀딩스
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.tail()
# Out:
# Date
# 2022-11-15    291500.0
# 2022-11-16    288000.0
# 2022-11-17    284000.0
# 2022-11-18    289500.0
# 2022-11-21    288500.0
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# %%
#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.679743
# p-value                          0.441579
# #Lags Used                       0.000000
# Number of Observations Used    244.000000
# Critical Value (1%)             -3.457438
# Critical Value (5%)             -2.873459
# Critical Value (10%)            -2.573122
# dtype: float64

# %%
#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
# 시계열 분해 결과 그래프
plt.subplot(411)
plt.plot(ts_log, label='Log Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='residual')
plt.legend(loc='best')

plt.tight_layout()

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.883222
# p-value                          0.002162
# #Lags Used                      11.000000
# Number of Observations Used    203.000000
# Critical Value (1%)             -3.462980
# Critical Value (5%)             -2.875885
# Critical Value (10%)            -2.574416
# dtype: float64

# %%
# 학습 및 테스트 데이타 분리
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
import pmdarima as pm
from pmdarima.arima import ndiffs

kpss_diffs = ndiffs(train_data, alpha=0.05, test='kpss', max_d=6)
adf_diffs = ndiffs(train_data, alpha=0.05, test='adf', max_d=6)
n_diffs = max(adf_diffs, kpss_diffs)

print(f"추정된 차수 d = {n_diffs}")
# Out:
# 추정된 차수 d = 1

# %%
### 적정 ARIMA 모수 찾기

# ACF, PACF 그려보기 -> p,q 구하기
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# -------------------------------------------
# 2차 차분 구하기
# diff_2 = diff_1.diff(periods=1).iloc[1:]
# diff_2.plot(title='Difference 2nd')
# augmented_dickey_fuller_test(diff_2)
# -------------------------------------------
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.530895e+01
# p-value                        4.212130e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.430000e+02
# Critical Value (1%)           -3.457551e+00
# Critical Value (5%)           -2.873509e+00
# Critical Value (10%)          -2.573148e+00
# dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA

# ARIMA 모델 훈련과 테스트
# Build and Train  Model
model = ARIMA(train_data, order=(2, 0, 19))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  220
# Model:                ARIMA(2, 0, 19)   Log Likelihood                 556.857
# Date:                Mon, 21 Nov 2022   AIC                          -1067.713
# Time:                        21:34:48   BIC                           -989.660
# Sample:                             0   HQIC                         -1036.193
#                                 - 220
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.4997      0.043    291.246      0.000      12.416      12.584
# ar.L1          1.3864      0.408      3.398      0.001       0.587       2.186
# ar.L2         -0.4437      0.377     -1.177      0.239      -1.183       0.295
# ma.L1         -0.3657      0.467     -0.783      0.433      -1.281       0.549
# ma.L2         -0.0010      0.105     -0.010      0.992      -0.208       0.206
# ma.L3          0.0395      0.093      0.423      0.672      -0.143       0.222
# ma.L4          0.0348      0.092      0.377      0.706      -0.146       0.216
# ma.L5          0.0501      0.079      0.630      0.529      -0.106       0.206
# ma.L6          0.1183      0.081      1.460      0.144      -0.040       0.277
# ma.L7         -0.0044      0.094     -0.047      0.963      -0.188       0.180
# ma.L8          0.0674      0.085      0.794      0.427      -0.099       0.234
# ma.L9         -0.0325      0.076     -0.427      0.670      -0.182       0.117
# ma.L10        -0.1389      0.090     -1.536      0.124      -0.316       0.038
# ma.L11         0.1693      0.133      1.269      0.204      -0.092       0.431
# ma.L12         0.1576      0.105      1.498      0.134      -0.049       0.364
# ma.L13         0.1694      0.124      1.367      0.172      -0.074       0.412
# ma.L14         0.0745      0.122      0.609      0.542      -0.165       0.314
# ma.L15         0.0407      0.104      0.390      0.696      -0.164       0.245
# ma.L16         0.0084      0.101      0.083      0.934      -0.190       0.207
# ma.L17         0.0565      0.097      0.581      0.561      -0.134       0.247
# ma.L18         0.3110      0.088      3.536      0.000       0.139       0.483
# ma.L19         0.0056      0.199      0.028      0.978      -0.385       0.396
# sigma2         0.0004   4.98e-05      7.054      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 0.01
# Prob(Q):                              0.84   Prob(JB):                         1.00
# Heteroskedasticity (H):               1.09   Skew:                             0.01
# Prob(H) (two-sided):                  0.71   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# 예측 및 그래프
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# 그래프 그리기 :Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()

# %% [markdown]
# # E-04 Stock Prediction ARIMA : 030200.KS.csv
#
# ### 2022-11-11 (금)
#
# ### 곽상혁
# https://github.com/docosa2/

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화

# %%
def plot_rolling_statistics(timeseries:pd.Series, window: int=12):    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %% [markdown]
# ## statsmodels 패키지에서 제공하는 adfuller 메서드를 호출

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %% [markdown]
# ## Time Series 생성

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/030200.KS.csv' # KT
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.tail()
# Out:
# Date
# 2022-11-15    36450.0
# 2022-11-16    36300.0
# 2022-11-17    36300.0
# 2022-11-18    36600.0
# 2022-11-21    36550.0
# Name: Close, dtype: float64

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

# %%
#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.778607
# p-value                          0.391133
# #Lags Used                       0.000000
# Number of Observations Used    244.000000
# Critical Value (1%)             -3.457438
# Critical Value (5%)             -2.873459
# Critical Value (10%)            -2.573122
# dtype: float64

# %%
#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
# 시계열 분해 결과 그래프
plt.subplot(411)
plt.plot(ts_log, label='Log Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal, label='seasonal')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='residual')
plt.legend(loc='best')

plt.tight_layout()

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.262997
# p-value                          0.000007
# #Lags Used                       0.000000
# Number of Observations Used    214.000000
# Critical Value (1%)             -3.461282
# Critical Value (5%)             -2.875143
# Critical Value (10%)            -2.574020
# dtype: float64

# %%
# 학습 및 테스트 데이타 분리
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
import pmdarima as pm
from pmdarima.arima import ndiffs

kpss_diffs = ndiffs(train_data, alpha=0.05, test='kpss', max_d=6)
adf_diffs = ndiffs(train_data, alpha=0.05, test='adf', max_d=6)
n_diffs = max(adf_diffs, kpss_diffs)

print(f"추정된 차수 d = {n_diffs}")
# Out:
# 추정된 차수 d = 1

# %%
### 적정 ARIMA 모수 찾기

# ACF, PACF 그려보기 -> p,q 구하기
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)

# -------------------------------------------
# 2차 차분 구하기
# diff_2 = diff_1.diff(periods=1).iloc[1:]
# diff_2.plot(title='Difference 2nd')
# augmented_dickey_fuller_test(diff_2)
# -------------------------------------------
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.625732e+01
# p-value                        3.595030e-29
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.430000e+02
# Critical Value (1%)           -3.457551e+00
# Critical Value (5%)           -2.873509e+00
# Critical Value (10%)          -2.573148e+00
# dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA

# ARIMA 모델 훈련과 테스트
# Build and Train  Model
model = ARIMA(train_data, order=(1, 4, 14))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  220
# Model:                ARIMA(1, 4, 14)   Log Likelihood                 580.251
# Date:                Mon, 21 Nov 2022   AIC                          -1128.502
# Time:                        21:34:50   BIC                          -1074.498
# Sample:                             0   HQIC                         -1106.684
#                                 - 220
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9821      0.056    -17.604      0.000      -1.091      -0.873
# ma.L1         -1.6857      0.234     -7.203      0.000      -2.144      -1.227
# ma.L2         -0.3408      0.586     -0.582      0.561      -1.489       0.807
# ma.L3          1.6599      0.496      3.346      0.001       0.687       2.632
# ma.L4         -0.5078      0.214     -2.367      0.018      -0.928      -0.087
# ma.L5         -0.1634      0.156     -1.045      0.296      -0.470       0.143
# ma.L6          0.2004      0.170      1.179      0.238      -0.133       0.534
# ma.L7         -0.0557      0.162     -0.343      0.731      -0.374       0.262
# ma.L8         -0.4580      0.178     -2.574      0.010      -0.807      -0.109
# ma.L9          0.6178      0.144      4.279      0.000       0.335       0.901
# ma.L10        -0.4629      0.209     -2.217      0.027      -0.872      -0.054
# ma.L11         0.1324      0.261      0.507      0.612      -0.379       0.644
# ma.L12         0.3897      0.286      1.361      0.173      -0.171       0.951
# ma.L13        -0.5069      0.220     -2.302      0.021      -0.938      -0.075
# ma.L14         0.1820      0.089      2.039      0.041       0.007       0.357
# sigma2         0.0002   4.35e-05      5.378      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.94   Jarque-Bera (JB):                14.16
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                            -0.14
# Prob(H) (two-sided):                  0.57   Kurtosis:                         4.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# 예측 및 그래프
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
# Out:
# /opt/anaconda3/envs/tutorial/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# 그래프 그리기 :Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
